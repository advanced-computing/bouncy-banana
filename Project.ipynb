# %%
# load libraries
import pandas as pd
import requests

# %%
# Import initial unemployment data via API
# Our API is from FRED (Federal Reserve Bank of St. Louis)

key = "aa9cd57aae80525dc171dbc517b39546"

url = "https://api.stlouisfed.org/fred/series/observations"

params = {
    "series_id": "NYICLAIMS",
    "api_key": key,
    "file_type": "json",
    "frequency": "w",
    # observation_start: (when we want to change the start time)
}

fred_initial_response = requests.get(url, params=params)
fred_initial_data = fred_initial_response.json()

# %%
# Creating Initial FRED Dataframe

fred_initial_df = pd.DataFrame(fred_initial_data["observations"])
fred_initial_df
# Out:
#      realtime_start realtime_end        date  value
# 0        2026-02-24   2026-02-24  1986-02-15  20647
# 1        2026-02-24   2026-02-24  1986-02-22  21499
# 2        2026-02-24   2026-02-24  1986-03-01  21738
# 3        2026-02-24   2026-02-24  1986-03-08  22049
# 4        2026-02-24   2026-02-24  1986-03-15  20144
# ...             ...          ...         ...    ...
# 2083     2026-02-24   2026-02-24  2026-01-17  18678
# 2084     2026-02-24   2026-02-24  2026-01-24  20417
# 2085     2026-02-24   2026-02-24  2026-01-31  23558
# 2086     2026-02-24   2026-02-24  2026-02-07  24382
# 2087     2026-02-24   2026-02-24  2026-02-14  16767
#
# [2088 rows x 4 columns]

# %%
# Data for continued unemployment filings after the initial filing

params = {
    "series_id": "NYCCLAIMS",
    "api_key": key,
    "file_type": "json",
    "frequency": "w",
    # observation_start: (when we want to change the start time)
}
fred_continued_response = requests.get(url, params=params)
fred_continued_data = fred_continued_response.json()

# %%
# Creating Continued Fred Dataframe

fred_continued_df = pd.DataFrame(fred_continued_data["observations"])
fred_continued_df
# Out:
#      realtime_start realtime_end        date     value
# 0        2026-02-24   2026-02-24  1986-02-08    234789
# 1        2026-02-24   2026-02-24  1986-02-15    224846
# 2        2026-02-24   2026-02-24  1986-02-22    238566
# 3        2026-02-24   2026-02-24  1986-03-01    231392
# 4        2026-02-24   2026-02-24  1986-03-08    230848
# ...             ...          ...         ...       ...
# 2083     2026-02-24   2026-02-24  2026-01-10  198436.0
# 2084     2026-02-24   2026-02-24  2026-01-17  194621.0
# 2085     2026-02-24   2026-02-24  2026-01-24  203505.0
# 2086     2026-02-24   2026-02-24  2026-01-31  215884.0
# 2087     2026-02-24   2026-02-24  2026-02-07  215869.0
#
# [2088 rows x 4 columns]

# %%
# Import NYC Eviction dataset from NYC Open Data via json

# https://data.cityofnewyork.us/City-Government/Evictions/6z8x-wfk4/about_data
eviction_data = pd.DataFrame()
url = "https://data.cityofnewyork.us/resource/6z8x-wfk4.json"
limit = 1000
offset = 0
loop = True
while loop == True:
    params = {"$limit": limit, "$offset": offset}
    r = requests.get(url, params=params)
    data = r.json()
    clean_pop = pd.json_normalize(data)
    eviction_data = pd.concat([eviction_data, clean_pop])

    if len(data) < limit:
        loop = False

    offset += limit

# View eviction data

eviction_data
# Out:
#     court_index_number docket_number                      eviction_address  \
# 0            322211/22        110319                   225 PARKSIDE AVENUE
# 1            324856/23        033980                     145 SEAMAN AVENUE
# 2           B327639/23        130479                   1051 TRINITY AVENUE
# 3           K097544/17        389788  795 PUTNAM AVENUE         ( STORE 2)
# 4            308643/22         50980                  264 LINDEN BOULEVARD
# ..                 ...           ...                                   ...
# 626         B311552/22        120976              1103A CASTLE HILL AVENUE
# 627         N079562/16        374711                  364 EAST 10TH STREET
# 628          326002/24        139315              578 EAST 163RD   STR EET
# 629           71610/16        330139                     3323 CORSA AVENUE
# 630         302807/23B        144815                    221-09 59TH AVENUE
#
#     eviction_apt_num            executed_date marshal_first_name  \
# 0                 2V  2023-01-17T00:00:00.000              Henry
# 1                2-F  2024-11-06T00:00:00.000               Gary
# 2                  2  2024-07-17T00:00:00.000            Darlene
# 3               STO#  2018-02-13T00:00:00.000            Richard
# 4                 2B  2025-09-08T00:00:00.000             Edward
# ..               ...                      ...                ...
# 626            STORE  2023-01-12T00:00:00.000            Darlene
# 627               6A  2017-02-21T00:00:00.000            Richard
# 628               6A  2025-07-09T00:00:00.000             Justin
# 629        1ST FLOOR  2017-07-06T00:00:00.000             Thomas
# 630                1  2025-07-16T00:00:00.000             Justin
#
#     marshal_last_name residential_commercial_ind    borough eviction_zip  \
# 0               Daley                Residential   BROOKLYN        11226
# 1                Rose                Residential  MANHATTAN        10034
# 2              Barone                Residential      BRONX        10456
# 3               McCoy                 Commercial   BROOKLYN        11221
# 4               Guida                Residential   BROOKLYN        11226
# ..                ...                        ...        ...          ...
# 626            Barone                 Commercial      BRONX        10472
# 627             McCoy                Residential  MANHATTAN        10009
# 628          Grossman                Residential      BRONX        10456
# 629               Bia                Residential      BRONX        10469
# 630          Grossman                Residential     QUEENS        11364
#
#             ejectment eviction_possession   latitude   longitude  \
# 0    Not an Ejectment          Possession  40.655486  -73.960305
# 1    Not an Ejectment          Possession  40.869024  -73.922459
# 2    Not an Ejectment          Possession  40.826410  -73.904500
# 3    Not an Ejectment          Possession        NaN         NaN
# 4    Not an Ejectment          Possession  40.652676  -73.949005
# ..                ...                 ...        ...         ...
# 626  Not an Ejectment          Possession  40.829858  -73.850564
# 627  Not an Ejectment          Possession  40.726419  -73.978854
# 628  Not an Ejectment          Possession  40.823899  -73.908088
# 629  Not an Ejectment          Possession  40.875129  -73.846445
# 630  Not an Ejectment          Possession  40.750394  -73.756791
#
#     community_board council_district census_tract      bin         bbl  \
# 0                 9               40        79802  3114646  3050260264
# 1                12               10          295  1064974  1022400017
# 2                 3               16          185  2004511  2026330029
# 3               NaN              NaN          NaN      NaN         NaN
# 4                17               40          818  3108502  3048680019
# ..              ...              ...          ...      ...         ...
# 626               9               18           78  2026434  2038090047
# 627               3                2           28  1004768  1003920017
# 628               3               17          141  2004377  2026200027
# 629              12               12          358  2119503  2047380028
# 630              11               23       138501  4161734  4075280077
#
#                                    nta
# 0    Prospect Lefferts Gardens-Wingate
# 1                   Marble Hill-Inwood
# 2                   Morrisania-Melrose
# 3                                  NaN
# 4                              Erasmus
# ..                                 ...
# 626              Westchester-Unionport
# 627                    Lower East Side
# 628                 Morrisania-Melrose
# 629    Eastchester-Edenwald-Baychester
# 630                    Oakland Gardens
#
# [123631 rows x 20 columns]

# %%
# Import NYC Health dataset from NYC Open Data via json

# https://data.cityofnewyork.us/City-Government/Evictions/6z8x-wfk4/about_data
health_data = pd.DataFrame()
url = "https://data.cityofnewyork.us/resource/csut-3wpr.json"
limit = 1000
offset = 0
loop = True
while loop == True:
    params = {"$limit": limit, "$offset": offset}
    r = requests.get(url, params=params)
    data = r.json()
    clean_pop = pd.json_normalize(data)
    health_data = pd.concat([health_data, clean_pop])

    if len(data) < limit:
        loop = False

    offset += limit

# View eviction data

health_data
# Out:
#            prevelance  year   q_1   q_2   q_3   q_4   q_5   q_6   q_7   q_8  \
# 0     Prevalence 2020  2020  12.6  12.4  28.8  22.3  10.9  16.6  25.4  71.8
# 1   Lower 95% CI 2020  2020  11.6  11.4  27.5  21.0  10.0  15.5  24.0  69.5
# 2   Upper 95% CI 2020  2020  13.7  13.6  30.3  23.7  12.0  17.8  26.8  74.0
# 3     Prevalence 2019  2019  12.7  12.4  16.2  22.1  11.9  18.9  24.8  70.7
# 4   Lower 95% CI 2019  2019  11.6  11.3  15.0  20.8  10.8  17.6  23.4  68.4
# 5   Upper 95% CI 2019  2019  14.0  13.5  17.5  23.5  13.0  20.2  26.2  72.9
# 6     Prevalence 2018  2018  11.6  11.1  15.6  23.6  12.8  17.8  25.7  69.1
# 7   Lower 95% CI 2018  2018  10.6  10.2  14.6  22.4  11.8  16.7  24.5  67.0
# 8   Upper 95% CI 2018  2018  12.6  12.1  16.8  25.0  13.8  19.0  27.1  71.1
# 9     Prevalence 2017  2017  11.8  10.3  15.2  23.0  13.4  17.3  25.1  69.9
# 10  Lower 95% CI 2017  2017  10.9   9.5  14.2  21.8  12.5  16.2  23.9  68.0
# 11  Upper 95% CI 2017  2017  12.8  11.2  16.3  24.2  14.4  18.4  26.3  71.6
# 12    Prevalence 2016  2016  10.9  10.5  16.8  22.7  13.1  17.0  23.6  68.5
# 13  Lower 95% CI 2016  2016  10.0   9.7  15.7  21.5  12.2  15.9  22.5  66.5
# 14  Upper 95% CI 2016  2016  11.8  11.5  17.9  23.9  14.1  18.1  24.9  70.4
# 15    Prevalence 2015  2015  12.6   9.9  16.3  23.7  14.3  17.2  24.1  69.9
# 16  Lower 95% CI 2015  2015  11.7   9.1  15.2  22.5  13.3  16.1  23.0  68.1
# 17  Upper 95% CI 2015  2015  13.6  10.8  17.4  24.9  15.3  18.3  25.3  71.6
# 18    Prevalence 2014  2014  13.8   9.6  15.6  22.5  13.9  16.5  24.7  69.9
# 19  Lower 95% CI 2014  2014  12.8   8.7  14.5  21.2  12.8  15.4  23.4  67.8
# 20  Upper 95% CI 2014  2014  14.8  10.5  16.7  23.8  14.9  17.7  26.0  72.0
# 21    Prevalence 2013  2013  20.9  11.2  19.1  23.3  16.1  18.2  23.4  69.0
# 22  Lower 95% CI 2013  2013  19.7  10.3  18.0  22.1  15.0  17.0  22.2  67.0
# 23  Upper 95% CI 2013  2013  22.2  12.2  20.3  24.6  17.2  19.4  24.7  71.0
# 24    Prevalence 2012  2012  19.8  11.1  18.3  28.2  15.5  19.6  24.2  68.5
# 25  Lower 95% CI 2012  2012  18.5  10.1  17.0  26.7  14.4  18.2  22.8  66.3
# 26  Upper 95% CI 2012  2012  21.3  12.2  19.7  29.6  16.8  20.9  25.5  70.5
# 27    Prevalence 2011  2011  18.6  10.7  16.9  29.9  14.8  17.9  23.7  68.6
# 28  Lower 95% CI 2011  2011  17.0   9.6  15.5  28.2  13.5  16.4  22.2  66.2
# 29  Upper 95% CI 2011  2011  20.3  12.0  18.5  31.7  16.3  19.6  25.3  70.8
# 30    Prevalence 2010  2010  16.7  10.3   NaN  30.3  14.0   NaN  23.4  67.5
# 31  Lower 95% CI 2010  2010  15.4   9.4   NaN  28.8  12.9   NaN  22.1  65.4
# 32  Upper 95% CI 2010  2010  18.0  11.4   NaN  31.8  15.3   NaN  24.8  69.4
#
#      q_9  q_10
# 0   80.8  69.8
# 1   79.6  66.1
# 2   82.0  73.2
# 3   76.6  67.6
# 4   75.2  64.2
# 5   77.9  70.7
# 6   76.8  62.8
# 7   75.6  59.7
# 8   77.9  65.8
# 9   76.8  66.1
# 10  75.7  63.4
# 11  77.9  68.8
# 12  78.0  65.4
# 13  76.8  62.4
# 14  79.1  68.3
# 15  77.4  65.5
# 16  76.3  62.7
# 17  78.4  68.1
# 18  77.8  64.2
# 19  76.6  60.7
# 20  78.9  67.6
# 21  76.9  66.8
# 22  75.7  63.7
# 23  78.0  69.8
# 24  78.7  61.8
# 25  77.5  58.5
# 26  79.9  64.9
# 27  78.2  67.4
# 28  76.7  63.9
# 29  79.6  70.7
# 30  79.1  62.3
# 31  77.8  59.4
# 32  80.3  65.1

# %%
health_data = health_data.rename(
    columns={
        "prevelance":"Prevelance",
        "q_1": "No Health Insurance",
        "q_2": "Do not get medical care",
        "q_3": "No Personal Doctor",
        "q_4": "Drinks 1 or more sugar-sweetened beverages per day",
        "q_5": "Smoking Status (current smokers)",
        "q_6": "Obesity",
        "q_7": "Binge Drinking",
        "q_8": "Colon cancer screening, adults age 50+ (colonoscopy)",
        "q_9": "Self-reported Health Status (excellent/very good/good)",
        "q_10": "Flu shot in last 12 months, adults ages 65+ (not age-adjusted)",
    }
)

health_data
# Out:
#            Prevelance  year No Health Insurance Do not get medical care  \
# 0     Prevalence 2020  2020                12.6                    12.4
# 1   Lower 95% CI 2020  2020                11.6                    11.4
# 2   Upper 95% CI 2020  2020                13.7                    13.6
# 3     Prevalence 2019  2019                12.7                    12.4
# 4   Lower 95% CI 2019  2019                11.6                    11.3
# 5   Upper 95% CI 2019  2019                14.0                    13.5
# 6     Prevalence 2018  2018                11.6                    11.1
# 7   Lower 95% CI 2018  2018                10.6                    10.2
# 8   Upper 95% CI 2018  2018                12.6                    12.1
# 9     Prevalence 2017  2017                11.8                    10.3
# 10  Lower 95% CI 2017  2017                10.9                     9.5
# 11  Upper 95% CI 2017  2017                12.8                    11.2
# 12    Prevalence 2016  2016                10.9                    10.5
# 13  Lower 95% CI 2016  2016                10.0                     9.7
# 14  Upper 95% CI 2016  2016                11.8                    11.5
# 15    Prevalence 2015  2015                12.6                     9.9
# 16  Lower 95% CI 2015  2015                11.7                     9.1
# 17  Upper 95% CI 2015  2015                13.6                    10.8
# 18    Prevalence 2014  2014                13.8                     9.6
# 19  Lower 95% CI 2014  2014                12.8                     8.7
# 20  Upper 95% CI 2014  2014                14.8                    10.5
# 21    Prevalence 2013  2013                20.9                    11.2
# 22  Lower 95% CI 2013  2013                19.7                    10.3
# 23  Upper 95% CI 2013  2013                22.2                    12.2
# 24    Prevalence 2012  2012                19.8                    11.1
# 25  Lower 95% CI 2012  2012                18.5                    10.1
# 26  Upper 95% CI 2012  2012                21.3                    12.2
# 27    Prevalence 2011  2011                18.6                    10.7
# 28  Lower 95% CI 2011  2011                17.0                     9.6
# 29  Upper 95% CI 2011  2011                20.3                    12.0
# 30    Prevalence 2010  2010                16.7                    10.3
# 31  Lower 95% CI 2010  2010                15.4                     9.4
# 32  Upper 95% CI 2010  2010                18.0                    11.4
#
#    No Personal Doctor Drinks 1 or more sugar-sweetened beverages per day  \
# 0                28.8                                               22.3
# 1                27.5                                               21.0
# 2                30.3                                               23.7
# 3                16.2                                               22.1
# 4                15.0                                               20.8
# 5                17.5                                               23.5
# 6                15.6                                               23.6
# 7                14.6                                               22.4
# 8                16.8                                               25.0
# 9                15.2                                               23.0
# 10               14.2                                               21.8
# 11               16.3                                               24.2
# 12               16.8                                               22.7
# 13               15.7                                               21.5
# 14               17.9                                               23.9
# 15               16.3                                               23.7
# 16               15.2                                               22.5
# 17               17.4                                               24.9
# 18               15.6                                               22.5
# 19               14.5                                               21.2
# 20               16.7                                               23.8
# 21               19.1                                               23.3
# 22               18.0                                               22.1
# 23               20.3                                               24.6
# 24               18.3                                               28.2
# 25               17.0                                               26.7
# 26               19.7                                               29.6
# 27               16.9                                               29.9
# 28               15.5                                               28.2
# 29               18.5                                               31.7
# 30                NaN                                               30.3
# 31                NaN                                               28.8
# 32                NaN                                               31.8
#
#    Smoking Status (current smokers) Obesity Binge Drinking  \
# 0                              10.9    16.6           25.4
# 1                              10.0    15.5           24.0
# 2                              12.0    17.8           26.8
# 3                              11.9    18.9           24.8
# 4                              10.8    17.6           23.4
# 5                              13.0    20.2           26.2
# 6                              12.8    17.8           25.7
# 7                              11.8    16.7           24.5
# 8                              13.8    19.0           27.1
# 9                              13.4    17.3           25.1
# 10                             12.5    16.2           23.9
# 11                             14.4    18.4           26.3
# 12                             13.1    17.0           23.6
# 13                             12.2    15.9           22.5
# 14                             14.1    18.1           24.9
# 15                             14.3    17.2           24.1
# 16                             13.3    16.1           23.0
# 17                             15.3    18.3           25.3
# 18                             13.9    16.5           24.7
# 19                             12.8    15.4           23.4
# 20                             14.9    17.7           26.0
# 21                             16.1    18.2           23.4
# 22                             15.0    17.0           22.2
# 23                             17.2    19.4           24.7
# 24                             15.5    19.6           24.2
# 25                             14.4    18.2           22.8
# 26                             16.8    20.9           25.5
# 27                             14.8    17.9           23.7
# 28                             13.5    16.4           22.2
# 29                             16.3    19.6           25.3
# 30                             14.0     NaN           23.4
# 31                             12.9     NaN           22.1
# 32                             15.3     NaN           24.8
#
#    Colon cancer screening, adults age 50+ (colonoscopy)  \
# 0                                                71.8
# 1                                                69.5
# 2                                                74.0
# 3                                                70.7
# 4                                                68.4
# 5                                                72.9
# 6                                                69.1
# 7                                                67.0
# 8                                                71.1
# 9                                                69.9
# 10                                               68.0
# 11                                               71.6
# 12                                               68.5
# 13                                               66.5
# 14                                               70.4
# 15                                               69.9
# 16                                               68.1
# 17                                               71.6
# 18                                               69.9
# 19                                               67.8
# 20                                               72.0
# 21                                               69.0
# 22                                               67.0
# 23                                               71.0
# 24                                               68.5
# 25                                               66.3
# 26                                               70.5
# 27                                               68.6
# 28                                               66.2
# 29                                               70.8
# 30                                               67.5
# 31                                               65.4
# 32                                               69.4
#
#    Self-reported Health Status (excellent/very good/good)  \
# 0                                                80.8
# 1                                                79.6
# 2                                                82.0
# 3                                                76.6
# 4                                                75.2
# 5                                                77.9
# 6                                                76.8
# 7                                                75.6
# 8                                                77.9
# 9                                                76.8
# 10                                               75.7
# 11                                               77.9
# 12                                               78.0
# 13                                               76.8
# 14                                               79.1
# 15                                               77.4
# 16                                               76.3
# 17                                               78.4
# 18                                               77.8
# 19                                               76.6
# 20                                               78.9
# 21                                               76.9
# 22                                               75.7
# 23                                               78.0
# 24                                               78.7
# 25                                               77.5
# 26                                               79.9
# 27                                               78.2
# 28                                               76.7
# 29                                               79.6
# 30                                               79.1
# 31                                               77.8
# 32                                               80.3
#
#    Flu shot in last 12 months, adults ages 65+ (not age-adjusted)
# 0                                                69.8
# 1                                                66.1
# 2                                                73.2
# 3                                                67.6
# 4                                                64.2
# 5                                                70.7
# 6                                                62.8
# 7                                                59.7
# 8                                                65.8
# 9                                                66.1
# 10                                               63.4
# 11                                               68.8
# 12                                               65.4
# 13                                               62.4
# 14                                               68.3
# 15                                               65.5
# 16                                               62.7
# 17                                               68.1
# 18                                               64.2
# 19                                               60.7
# 20                                               67.6
# 21                                               66.8
# 22                                               63.7
# 23                                               69.8
# 24                                               61.8
# 25                                               58.5
# 26                                               64.9
# 27                                               67.4
# 28                                               63.9
# 29                                               70.7
# 30                                               62.3
# 31                                               59.4
# 32                                               65.1

# %%
def health_year_filter(data, year,metric):
    filtered = data[data["year"] == str(year)]
    filtered = filtered[filtered["Prevelance"].str.contains("Prevalence")]

    return filtered[str(metric)].iloc[0]

# %%
health_year_filter(health_data,2018,"Do not get medical care")
# Out:
# '11.1'
