# %%
# Library Jargon
import requests
import pandas as pd

# %%
# Initial unemployment data import
# We using FRED :D

key = "aa9cd57aae80525dc171dbc517b39546"

url = "https://api.stlouisfed.org/fred/series/observations"

params = {
    "series_id": "NYICLAIMS",
    "api_key": key,
    "file_type": "json",
    "frequency": "w"
    #observation_start: (when we want to change the start time)
}

fred_initial_response = requests.get(url, params = params)
fred_initial_data = fred_initial_response.json()

# %%
# Creating Initial FRED Dataframe

fred_initial_df = pd.DataFrame(fred_initial_data["observations"])
fred_initial_df
# Out:
#      realtime_start realtime_end        date  value
# 0        2026-02-14   2026-02-14  1986-02-15  20647
# 1        2026-02-14   2026-02-14  1986-02-22  21499
# 2        2026-02-14   2026-02-14  1986-03-01  21738
# 3        2026-02-14   2026-02-14  1986-03-08  22049
# 4        2026-02-14   2026-02-14  1986-03-15  20144
# ...             ...          ...         ...    ...
# 2082     2026-02-14   2026-02-14  2026-01-10  28142
# 2083     2026-02-14   2026-02-14  2026-01-17  18678
# 2084     2026-02-14   2026-02-14  2026-01-24  20417
# 2085     2026-02-14   2026-02-14  2026-01-31  23558
# 2086     2026-02-14   2026-02-14  2026-02-07  24382
#
# [2087 rows x 4 columns]

# %%
# Continued unemployment data

params = {
    "series_id": "NYCCLAIMS",
    "api_key": key,
    "file_type": "json",
    "frequency": "w"
    #observation_start: (when we want to change the start time)
}
fred_continued_response = requests.get(url, params = params)
fred_continued_data = fred_continued_response.json()

# %%
# Creating Continued Fred Dataframe

fred_continued_df = pd.DataFrame(fred_continued_data["observations"])
fred_continued_df
# Out:
#      realtime_start realtime_end        date     value
# 0        2026-02-14   2026-02-14  1986-02-08    234789
# 1        2026-02-14   2026-02-14  1986-02-15    224846
# 2        2026-02-14   2026-02-14  1986-02-22    238566
# 3        2026-02-14   2026-02-14  1986-03-01    231392
# 4        2026-02-14   2026-02-14  1986-03-08    230848
# ...             ...          ...         ...       ...
# 2082     2026-02-14   2026-02-14  2026-01-03  219921.0
# 2083     2026-02-14   2026-02-14  2026-01-10  198436.0
# 2084     2026-02-14   2026-02-14  2026-01-17  194621.0
# 2085     2026-02-14   2026-02-14  2026-01-24  203505.0
# 2086     2026-02-14   2026-02-14  2026-01-31  215884.0
#
# [2087 rows x 4 columns]

# %%
#Second Dataset

# https://data.cityofnewyork.us/City-Government/Evictions/6z8x-wfk4/about_data
eviction_data = pd.DataFrame()
url = "https://data.cityofnewyork.us/resource/6z8x-wfk4.json"
limit = 1000
offset = 0
loop = True
while loop == True:
    params = {"$limit": limit, "$offset": offset}
    r = requests.get(url, params = params)
    data =r.json()
    clean_pop = pd.json_normalize(data)
    eviction_data = pd.concat([eviction_data,clean_pop])

    if len(data) < limit:
        loop = False
    
    offset += limit

eviction_data
# Out:
#     court_index_number docket_number          eviction_address  \
# 0            309118/20        004044            1338 BERGEN ST
# 1            K68035/18        106901       560 WINTHROP STREET
# 2            R50849/18        089304         7 NAVY PIER COURT
# 3           330748/24B        136198       2685 UNIVERSITY AVE
# 4             52601/17        340776      1057 SHERIDAN AVENUE
# ..                 ...           ...                       ...
# 279         N305693/25        121386    80 NORTH MOORE STREE T
# 280          302068/23        120484  1506 EAST 98TH   STR EET
# 281         B322758/22        122806      1297 CHISHOLM STREET
# 282          320769/23        129028           361 TROY AVENUE
# 283           92773/18        027128       10317 GLENWOOD ROAD
#
#     eviction_apt_num            executed_date marshal_first_name  \
# 0                  5  2025-11-25T00:00:00.000         Salavatore
# 1                921  2018-10-11T00:00:00.000            Darlene
# 2               1093  2018-07-17T00:00:00.000             Ileana
# 3                16C  2025-08-25T00:00:00.000            Darlene
# 4                 1C  2018-07-26T00:00:00.000             Thomas
# ..               ...                      ...                ...
# 279              20A  2025-09-10T00:00:00.000             Ileana
# 280        2ND FLOOR  2024-05-13T00:00:00.000             Justin
# 281                1  2023-09-12T00:00:00.000            Darlene
# 282                1  2024-06-10T00:00:00.000             Justin
# 283              NaN  2019-05-01T00:00:00.000               Gary
#
#     marshal_last_name residential_commercial_ind        borough eviction_zip  \
# 0              Giglio                Residential       BROOKLYN        11213
# 1              Barone                Residential       BROOKLYN        11203
# 2              Rivera                Residential  STATEN ISLAND        10304
# 3              Barone                Residential          BRONX        10468
# 4                 Bia                Residential          BRONX        10456
# ..                ...                        ...            ...          ...
# 279            Rivera                Residential      MANHATTAN        10013
# 280          Grossman                Residential       BROOKLYN        11236
# 281            Barone                Residential          BRONX        10459
# 282          Grossman                Residential       BROOKLYN        11213
# 283              Rose                 Commercial       BROOKLYN        11236
#
#             ejectment eviction_possession   latitude   longitude  \
# 0    Not an Ejectment          Possession  40.675561  -73.940256
# 1    Not an Ejectment          Possession  40.657646  -73.941519
# 2    Not an Ejectment          Possession  40.628828  -74.074387
# 3    Not an Ejectment          Possession  40.868459  -73.900944
# 4    Not an Ejectment          Possession  40.830596  -73.918804
# ..                ...                 ...        ...         ...
# 279  Not an Ejectment          Possession  40.720145  -74.010552
# 280  Not an Ejectment          Possession  40.636700  -73.891423
# 281  Not an Ejectment          Possession  40.830347  -73.895577
# 282  Not an Ejectment          Possession  40.666048  -73.936930
# 283  Not an Ejectment          Possession  40.648286  -73.897516
#
#     community_board council_district census_tract      bin         bbl  \
# 0                 8               36          311  3030822  3012230023
# 1                 9               40          808  3424559  3048290005
# 2                 1               49           21  5158986  5004877501
# 3                 8               14        26701  2015260  2032480049
# 4                 4               16        18102  2002729  2024560023
# ..              ...              ...          ...      ...         ...
# 279               1                1           39  1083157  1001420025
# 280              18               46         1022  3233730  3082810069
# 281               3               16          125  2116574  2029700167
# 282               9               35          353  3038041  3014130007
# 283              18               42          974  3229459  3081720001
#
#                                         nta
# 0                       Crown Heights North
# 1         Prospect Lefferts Gardens-Wingate
# 2                        Stapleton-Rosebank
# 3                     Van Cortlandt Village
# 4          East Concourse-Concourse Village
# ..                                      ...
# 279  SoHo-TriBeCa-Civic Center-Little Italy
# 280                                Canarsie
# 281                      Morrisania-Melrose
# 282                     Crown Heights North
# 283                                Canarsie
#
# [123284 rows x 20 columns]

# %%
# Potential datasets :^)
# https://www.opendatanetwork.com/dataset/data.cityofnewyork.us/8h9b-rp9u (Maybe???)
